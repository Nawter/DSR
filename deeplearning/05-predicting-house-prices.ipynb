# %%
from keras.datasets import boston_housing
# Out:
# Using TensorFlow backend.

# %%
(train_data, train_targets) ,(test_data, test_targets)= boston_housing.load_data()
from sklearn.datasets import load_boston
boston = load_boston()
print(boston.DESCR)
# Out:
# Boston House Prices dataset
# ===========================
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# http://archive.ics.uci.edu/ml/datasets/Housing
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# **References**
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#    - many more! (see http://archive.ics.uci.edu/ml/datasets/Housing)

# %%
import numpy as np
print(len(train_data), 'train sequences')
print(len(test_data), 'test sequences')
print(len(train_targets), 'train targets')
print(len(test_targets), 'test targets')

num_classes = np.max(train_targets) + 1
print(num_classes, 'classes')
# Out:
# 404 train sequences
# 102 test sequences
# 404 train targets
# 102 test targets
# 51.0 classes

# %%
print(train_data.shape)
print(train_targets.shape)
# Out:
# (404, 13)
# (404,)

# %%
print(train_targets[0:100])
print(np.min(train_targets))
print(np.max(train_targets))
print(np.mean(train_targets))
# Out:
# [15.2 42.3 50.  21.1 17.7 18.5 11.3 15.6 15.6 14.4 12.1 17.9 23.1 19.9
#  15.7  8.8 50.  22.5 24.1 27.5 10.9 30.8 32.9 24.  18.5 13.3 22.9 34.7
#  16.6 17.5 22.3 16.1 14.9 23.1 34.9 25.  13.9 13.1 20.4 20.  15.2 24.7
#  22.2 16.7 12.7 15.6 18.4 21.  30.1 15.1 18.7  9.6 31.5 24.8 19.1 22.
#  14.5 11.  32.  29.4 20.3 24.4 14.6 19.5 14.1 14.3 15.6 10.5  6.3 19.3
#  19.3 13.4 36.4 17.8 13.5 16.5  8.3 14.3 16.  13.4 28.6 43.5 20.2 22.
#  23.  20.7 12.5 48.5 14.6 13.4 23.7 50.  21.7 39.8 38.7 22.2 34.9 22.5
#  31.1 28.7]
# 5.0
# 50.0
# 22.395049504950492

# %%
print(train_data[0])
# Out:
# [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]

# %%
print(np.min(train_data, axis=0))
print(np.mean(train_data, axis=0))
print(np.max(train_data, axis=0))
# Out:
# [6.3200e-03 0.0000e+00 4.6000e-01 0.0000e+00 3.8500e-01 3.5610e+00
#  2.9000e+00 1.1296e+00 1.0000e+00 1.8800e+02 1.2600e+01 3.2000e-01
#  1.7300e+00]
# [3.74511057e+00 1.14801980e+01 1.11044307e+01 6.18811881e-02
#  5.57355941e-01 6.26708168e+00 6.90106436e+01 3.74027079e+00
#  9.44059406e+00 4.05898515e+02 1.84759901e+01 3.54783168e+02
#  1.27408168e+01]
# [ 88.9762 100.      27.74     1.       0.871    8.725  100.      10.7103
#   24.     711.      22.     396.9     37.97  ]

# %%
print(np.max(train_data))
# Out:
# 711.0

# %%
#normalize the training data
mean = train_data.mean(axis=0)
print(mean)
train_data -= mean
std = train_data.std(axis=0)
print(std)
train_data /= std
#normalize the test data
test_data -= mean
test_data /= std
# Out:
# [3.74511057e+00 1.14801980e+01 1.11044307e+01 6.18811881e-02
#  5.57355941e-01 6.26708168e+00 6.90106436e+01 3.74027079e+00
#  9.44059406e+00 4.05898515e+02 1.84759901e+01 3.54783168e+02
#  1.27408168e+01]
# [9.22929073e+00 2.37382770e+01 6.80287253e+00 2.40939633e-01
#  1.17147847e-01 7.08908627e-01 2.79060634e+01 2.02770050e+00
#  8.68758849e+00 1.66168506e+02 2.19765689e+00 9.39946015e+01
#  7.24556085e+00]

# %%
print(train_data[0])
# Out:
# [-0.27224633 -0.48361547 -0.43576161 -0.25683275 -0.1652266  -0.1764426
#   0.81306188  0.1166983  -0.62624905 -0.59517003  1.14850044  0.44807713
#   0.8252202 ]

# %%
print(np.min(train_data, axis=0))
print(np.mean(train_data, axis=0))
print(np.max(train_data, axis=0))
# Out:
# [-0.40510053 -0.48361547 -1.56469648 -0.25683275 -1.47126853 -3.81725032
#  -2.36904226 -1.28750316 -0.97156928 -1.31131055 -2.67375227 -3.77110135
#  -1.51966384]
# [-1.01541438e-16  1.09923072e-17  1.80933376e-15 -7.80453809e-17
#  -5.25047552e-15  6.43187374e-15  2.98441140e-16  4.94653823e-16
#   1.12671149e-17 -1.05526149e-16  2.36614908e-14  5.96710525e-15
#   6.13920356e-16]
# [9.23484718 3.72899018 2.44537425 3.89358447 2.67733525 3.46718635
#  1.11048828 3.43740568 1.67588577 1.83609694 1.60353052 0.44807713
#  3.48201936]

# %%
from keras import models
from keras import layers

def build_model():
  
  model = models.Sequential()
  # there is no rules
  model.add(layers.Dense(64,activation="relu", input_shape=(13,)))
  model.add(layers.Dense(64,activation="relu"))
  model.add(layers.Dense(1))
  
  # Loss mse = Mean square error 
  # Metric mae = Mean absolute error
  #  optimizer = "rmsprop",
  model.compile(optimizer="adam",loss="mse", metrics=["mae"])
  
  return model

build_model().summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# four fold cross validation
k = 4
num_val_samples = len(train_data) // k
print(num_val_samples)
num_epochs = 50
all_scores = []

for i in range(k):
  print("Fold:",i)
  
  val_data = train_data[i * num_val_samples:(i + 1) * num_val_samples]
  val_targets = train_targets[i * num_val_samples:(i + 1) * num_val_samples]
  
  data_left = train_data[:i * num_val_samples]
  data_right = train_data[(i + 1) * num_val_samples:]
  partial_train_data = np.concatenate([data_left, data_right])
    
  targets_left = train_targets[:i * num_val_samples]
  targets_right = train_targets[(i + 1) * num_val_samples:]
  partial_train_targets = np.concatenate([targets_left, targets_right])
  
  model = build_model()
  model.fit(
  partial_train_data, partial_train_targets,
  epochs = num_epochs,
  batch_size = 1    
  )
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores.append(val_mae)
# Out:
# 101
# Fold: 0
# Epoch 1/50
# 303/303 [==============================] - 0s 1ms/step - loss: 211.5651 - mean_absolute_error: 10.7360
# Epoch 2/50
# 303/303 [==============================] - 0s 1ms/step - loss: 26.9672 - mean_absolute_error: 3.6715
# Epoch 3/50
# 303/303 [==============================] - 0s 1ms/step - loss: 18.0856 - mean_absolute_error: 3.0265
# Epoch 4/50
# 303/303 [==============================] - 0s 1ms/step - loss: 14.9862 - mean_absolute_error: 2.6951
# Epoch 5/50
# 303/303 [==============================] - 0s 1ms/step - loss: 13.7177 - mean_absolute_error: 2.6061
# Epoch 6/50
# 303/303 [==============================] - 0s 1ms/step - loss: 13.2804 - mean_absolute_error: 2.5742
# Epoch 7/50
# 303/303 [==============================] - 0s 1ms/step - loss: 12.8622 - mean_absolute_error: 2.4748
# Epoch 8/50
# 303/303 [==============================] - 0s 1ms/step - loss: 11.6120 - mean_absolute_error: 2.4379
# Epoch 9/50
# 303/303 [==============================] - 0s 1ms/step - loss: 11.5291 - mean_absolute_error: 2.4155
# Epoch 10/50
# 303/303 [==============================] - 0s 1ms/step - loss: 11.1089 - mean_absolute_error: 2.3773
# Epoch 11/50
# 303/303 [==============================] - 0s 1ms/step - loss: 10.3229 - mean_absolute_error: 2.2553
# Epoch 12/50
# 303/303 [==============================] - 0s 1ms/step - loss: 11.1256 - mean_absolute_error: 2.3701
# Epoch 13/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.4320 - mean_absolute_error: 2.1879
# Epoch 14/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.5890 - mean_absolute_error: 2.2535
# Epoch 15/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.2580 - mean_absolute_error: 2.1171
# Epoch 16/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.1963 - mean_absolute_error: 2.1474
# Epoch 17/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.3070 - mean_absolute_error: 2.1299
# Epoch 18/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.2142 - mean_absolute_error: 2.2322
# Epoch 19/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.3819 - mean_absolute_error: 2.0601
# Epoch 20/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.6924 - mean_absolute_error: 2.1829
# Epoch 21/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.0007 - mean_absolute_error: 2.0460
# Epoch 22/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.0903 - mean_absolute_error: 2.0259
# Epoch 23/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.0797 - mean_absolute_error: 2.0145
# Epoch 24/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.9428 - mean_absolute_error: 1.9796
# Epoch 25/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.9561 - mean_absolute_error: 2.0392
# Epoch 26/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.7330 - mean_absolute_error: 2.0068
# Epoch 27/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.4202 - mean_absolute_error: 1.9984
# Epoch 28/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.9992 - mean_absolute_error: 1.9298
# Epoch 29/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.1848 - mean_absolute_error: 1.8992
# Epoch 30/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.4010 - mean_absolute_error: 2.0191
# Epoch 31/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.9524 - mean_absolute_error: 1.9580
# Epoch 32/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.6538 - mean_absolute_error: 1.8826
# Epoch 33/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.4612 - mean_absolute_error: 1.8322
# Epoch 34/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.0402 - mean_absolute_error: 1.9256
# Epoch 35/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.2193 - mean_absolute_error: 1.8243
# Epoch 36/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.1263 - mean_absolute_error: 1.9249
# Epoch 37/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.2061 - mean_absolute_error: 1.7802
# Epoch 38/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.6917 - mean_absolute_error: 1.8004
# Epoch 39/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.9297 - mean_absolute_error: 1.7372
# Epoch 40/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.8835 - mean_absolute_error: 1.7827
# Epoch 41/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.8012 - mean_absolute_error: 1.7764
# Epoch 42/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.9046 - mean_absolute_error: 1.7560
# Epoch 43/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.8492 - mean_absolute_error: 1.6944
# Epoch 44/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.5279 - mean_absolute_error: 1.6913
# Epoch 45/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.3610 - mean_absolute_error: 1.6775
# Epoch 46/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.3892 - mean_absolute_error: 1.7044
# Epoch 47/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.6042 - mean_absolute_error: 1.7528
# Epoch 48/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.3811 - mean_absolute_error: 1.6954
# Epoch 49/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.6240 - mean_absolute_error: 1.7333
# Epoch 50/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.5546 - mean_absolute_error: 1.5667
# Fold: 1
# Epoch 1/50
# 303/303 [==============================] - 0s 1ms/step - loss: 204.8180 - mean_absolute_error: 10.7960
# Epoch 2/50
# 303/303 [==============================] - 0s 1ms/step - loss: 23.6960 - mean_absolute_error: 3.3462
# Epoch 3/50
# 303/303 [==============================] - 0s 1ms/step - loss: 17.1692 - mean_absolute_error: 2.8971
# Epoch 4/50
# 303/303 [==============================] - 0s 1ms/step - loss: 14.7243 - mean_absolute_error: 2.7086
# Epoch 5/50
# 303/303 [==============================] - 0s 1ms/step - loss: 12.8790 - mean_absolute_error: 2.5366
# Epoch 6/50
# 303/303 [==============================] - 0s 1ms/step - loss: 12.3434 - mean_absolute_error: 2.5100
# Epoch 7/50
# 303/303 [==============================] - 0s 1ms/step - loss: 11.7188 - mean_absolute_error: 2.3799
# Epoch 8/50
# 303/303 [==============================] - 0s 1ms/step - loss: 10.8352 - mean_absolute_error: 2.3446
# Epoch 9/50
# 303/303 [==============================] - 0s 1ms/step - loss: 10.4603 - mean_absolute_error: 2.3041
# Epoch 10/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.9064 - mean_absolute_error: 2.2462
# Epoch 11/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.9860 - mean_absolute_error: 2.2922
# Epoch 12/50
# 303/303 [==============================] - 1s 2ms/step - loss: 9.5618 - mean_absolute_error: 2.2163
# Epoch 13/50
# 303/303 [==============================] - 1s 2ms/step - loss: 9.1347 - mean_absolute_error: 2.1653
# Epoch 14/50
# 303/303 [==============================] - 1s 2ms/step - loss: 9.0698 - mean_absolute_error: 2.1207
# Epoch 15/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.0111 - mean_absolute_error: 2.1226
# Epoch 16/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.6508 - mean_absolute_error: 2.0392
# Epoch 17/50
# 303/303 [==============================] - 1s 2ms/step - loss: 8.3895 - mean_absolute_error: 2.1164
# Epoch 18/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.6076 - mean_absolute_error: 2.0930
# Epoch 19/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.3503 - mean_absolute_error: 2.0362
# Epoch 20/50
# 303/303 [==============================] - 1s 2ms/step - loss: 7.7155 - mean_absolute_error: 2.0085
# Epoch 21/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.6684 - mean_absolute_error: 2.0018
# Epoch 22/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.2538 - mean_absolute_error: 1.9721
# Epoch 23/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.6444 - mean_absolute_error: 1.9707
# Epoch 24/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.1747 - mean_absolute_error: 1.9041
# Epoch 25/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.9821 - mean_absolute_error: 1.8996
# Epoch 26/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.8284 - mean_absolute_error: 1.8657
# Epoch 27/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.5589 - mean_absolute_error: 1.9030
# Epoch 28/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.3171 - mean_absolute_error: 1.7695
# Epoch 29/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.4655 - mean_absolute_error: 1.8392
# Epoch 30/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.1098 - mean_absolute_error: 1.8369
# Epoch 31/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.8654 - mean_absolute_error: 1.7737
# Epoch 32/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.9878 - mean_absolute_error: 1.7815
# Epoch 33/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.5982 - mean_absolute_error: 1.7398
# Epoch 34/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.5688 - mean_absolute_error: 1.7077
# Epoch 35/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.5342 - mean_absolute_error: 1.7476
# Epoch 36/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.4957 - mean_absolute_error: 1.7582
# Epoch 37/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.3830 - mean_absolute_error: 1.6962
# Epoch 38/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.9968 - mean_absolute_error: 1.6687
# Epoch 39/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.0389 - mean_absolute_error: 1.6607
# Epoch 40/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.9487 - mean_absolute_error: 1.6494
# Epoch 41/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.5033 - mean_absolute_error: 1.5360
# Epoch 42/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.5932 - mean_absolute_error: 1.5643
# Epoch 43/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.3300 - mean_absolute_error: 1.5334
# Epoch 44/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.4530 - mean_absolute_error: 1.5109
# Epoch 45/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.4985 - mean_absolute_error: 1.5750
# Epoch 46/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.1673 - mean_absolute_error: 1.5450
# Epoch 47/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.0866 - mean_absolute_error: 1.4408
# Epoch 48/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.9962 - mean_absolute_error: 1.4933
# Epoch 49/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.1923 - mean_absolute_error: 1.5324
# Epoch 50/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.0525 - mean_absolute_error: 1.4911
# Fold: 2
# Epoch 1/50
# 303/303 [==============================] - 1s 2ms/step - loss: 183.7776 - mean_absolute_error: 9.6452
# Epoch 2/50
# 303/303 [==============================] - 0s 2ms/step - loss: 22.3059 - mean_absolute_error: 3.3247
# Epoch 3/50
# 303/303 [==============================] - 0s 1ms/step - loss: 16.1675 - mean_absolute_error: 2.9266
# Epoch 4/50
# 303/303 [==============================] - 0s 1ms/step - loss: 13.9098 - mean_absolute_error: 2.7179
# Epoch 5/50
# 303/303 [==============================] - 1s 2ms/step - loss: 12.2863 - mean_absolute_error: 2.5392
# Epoch 6/50
# 303/303 [==============================] - 0s 1ms/step - loss: 10.9301 - mean_absolute_error: 2.4235
# Epoch 7/50
# 303/303 [==============================] - 0s 1ms/step - loss: 10.7346 - mean_absolute_error: 2.3935
# Epoch 8/50
# 303/303 [==============================] - 1s 2ms/step - loss: 9.9879 - mean_absolute_error: 2.3475
# Epoch 9/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.1208 - mean_absolute_error: 2.1922
# Epoch 10/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.4667 - mean_absolute_error: 2.1812
# Epoch 11/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.4124 - mean_absolute_error: 2.1048
# Epoch 12/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.0202 - mean_absolute_error: 2.1376
# Epoch 13/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.7732 - mean_absolute_error: 2.0237
# Epoch 14/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.7653 - mean_absolute_error: 2.0391
# Epoch 15/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.7977 - mean_absolute_error: 2.1053
# Epoch 16/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.4909 - mean_absolute_error: 2.0589
# Epoch 17/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.4149 - mean_absolute_error: 2.0035
# Epoch 18/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.5637 - mean_absolute_error: 1.9555
# Epoch 19/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.1032 - mean_absolute_error: 1.9653
# Epoch 20/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.7512 - mean_absolute_error: 1.9792
# Epoch 21/50
# 303/303 [==============================] - 0s 2ms/step - loss: 6.4083 - mean_absolute_error: 1.8877
# Epoch 22/50
# 303/303 [==============================] - 1s 2ms/step - loss: 6.0639 - mean_absolute_error: 1.8577
# Epoch 23/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.2967 - mean_absolute_error: 1.8215
# Epoch 24/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.7055 - mean_absolute_error: 1.7677
# Epoch 25/50
# 303/303 [==============================] - 0s 2ms/step - loss: 5.8227 - mean_absolute_error: 1.8135
# Epoch 26/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.1060 - mean_absolute_error: 1.8853
# Epoch 27/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.0601 - mean_absolute_error: 1.8229
# Epoch 28/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.7320 - mean_absolute_error: 1.7652
# Epoch 29/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.6182 - mean_absolute_error: 1.7875
# Epoch 30/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.8201 - mean_absolute_error: 1.6466
# Epoch 31/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.3728 - mean_absolute_error: 1.7010
# Epoch 32/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.5335 - mean_absolute_error: 1.6154
# Epoch 33/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.1542 - mean_absolute_error: 1.6782
# Epoch 34/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.6911 - mean_absolute_error: 1.6273
# Epoch 35/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.8433 - mean_absolute_error: 1.6455
# Epoch 36/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.6017 - mean_absolute_error: 1.5741
# Epoch 37/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.7488 - mean_absolute_error: 1.6500
# Epoch 38/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.9085 - mean_absolute_error: 1.5387
# Epoch 39/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.0688 - mean_absolute_error: 1.4943
# Epoch 40/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.4084 - mean_absolute_error: 1.5292
# Epoch 41/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.1116 - mean_absolute_error: 1.5352
# Epoch 42/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.2530 - mean_absolute_error: 1.5360
# Epoch 43/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.8341 - mean_absolute_error: 1.5139
# Epoch 44/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.9623 - mean_absolute_error: 1.5220
# Epoch 45/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.6594 - mean_absolute_error: 1.4553
# Epoch 46/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.3159 - mean_absolute_error: 1.5433
# Epoch 47/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.8001 - mean_absolute_error: 1.4601
# Epoch 48/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.5748 - mean_absolute_error: 1.4447
# Epoch 49/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.5386 - mean_absolute_error: 1.4351
# Epoch 50/50
# 303/303 [==============================] - 0s 1ms/step - loss: 3.2714 - mean_absolute_error: 1.3760
# Fold: 3
# Epoch 1/50
# 303/303 [==============================] - 1s 2ms/step - loss: 217.1078 - mean_absolute_error: 11.2228
# Epoch 2/50
# 303/303 [==============================] - 0s 1ms/step - loss: 28.6693 - mean_absolute_error: 3.6705
# Epoch 3/50
# 303/303 [==============================] - 0s 1ms/step - loss: 19.2630 - mean_absolute_error: 3.1103
# Epoch 4/50
# 303/303 [==============================] - 0s 1ms/step - loss: 15.2392 - mean_absolute_error: 2.6441
# Epoch 5/50
# 303/303 [==============================] - 0s 1ms/step - loss: 12.8823 - mean_absolute_error: 2.5018
# Epoch 6/50
# 303/303 [==============================] - 0s 1ms/step - loss: 11.3324 - mean_absolute_error: 2.3513
# Epoch 7/50
# 303/303 [==============================] - 0s 1ms/step - loss: 10.1967 - mean_absolute_error: 2.2317
# Epoch 8/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.6949 - mean_absolute_error: 2.2784
# Epoch 9/50
# 303/303 [==============================] - 0s 1ms/step - loss: 10.0426 - mean_absolute_error: 2.2340
# Epoch 10/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.8965 - mean_absolute_error: 2.2311
# Epoch 11/50
# 303/303 [==============================] - 0s 1ms/step - loss: 9.5489 - mean_absolute_error: 2.1605
# Epoch 12/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.8840 - mean_absolute_error: 2.0837
# Epoch 13/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.6013 - mean_absolute_error: 2.0617
# Epoch 14/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.6185 - mean_absolute_error: 2.1012
# Epoch 15/50
# 303/303 [==============================] - 0s 1ms/step - loss: 8.2399 - mean_absolute_error: 2.0049
# Epoch 16/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.6334 - mean_absolute_error: 1.9095
# Epoch 17/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.6587 - mean_absolute_error: 1.9584
# Epoch 18/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.5784 - mean_absolute_error: 1.9428
# Epoch 19/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.7186 - mean_absolute_error: 1.8259
# Epoch 20/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.2901 - mean_absolute_error: 1.8742
# Epoch 21/50
# 303/303 [==============================] - 0s 1ms/step - loss: 7.1648 - mean_absolute_error: 1.8754
# Epoch 22/50
# 303/303 [==============================] - 0s 2ms/step - loss: 7.0424 - mean_absolute_error: 1.8047
# Epoch 23/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.4813 - mean_absolute_error: 1.7781
# Epoch 24/50
# 303/303 [==============================] - 0s 2ms/step - loss: 6.7591 - mean_absolute_error: 1.8113
# Epoch 25/50
# 303/303 [==============================] - 0s 2ms/step - loss: 6.2535 - mean_absolute_error: 1.8026
# Epoch 26/50
# 303/303 [==============================] - 0s 1ms/step - loss: 6.1946 - mean_absolute_error: 1.7583
# Epoch 27/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.9662 - mean_absolute_error: 1.7026
# Epoch 28/50
# 303/303 [==============================] - 0s 2ms/step - loss: 6.0319 - mean_absolute_error: 1.7157
# Epoch 29/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.8740 - mean_absolute_error: 1.6976
# Epoch 30/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.6529 - mean_absolute_error: 1.6190
# Epoch 31/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.5130 - mean_absolute_error: 1.6690
# Epoch 32/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.3217 - mean_absolute_error: 1.6047
# Epoch 33/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.9853 - mean_absolute_error: 1.5942
# Epoch 34/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.2307 - mean_absolute_error: 1.5846
# Epoch 35/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.0824 - mean_absolute_error: 1.5927
# Epoch 36/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.8165 - mean_absolute_error: 1.5240
# Epoch 37/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.9306 - mean_absolute_error: 1.5915
# Epoch 38/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.8600 - mean_absolute_error: 1.5066
# Epoch 39/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.3501 - mean_absolute_error: 1.4620
# Epoch 40/50
# 303/303 [==============================] - 0s 1ms/step - loss: 5.5631 - mean_absolute_error: 1.7064
# Epoch 41/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.4189 - mean_absolute_error: 1.4999
# Epoch 42/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.3276 - mean_absolute_error: 1.4602
# Epoch 43/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.0792 - mean_absolute_error: 1.3789
# Epoch 44/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.7214 - mean_absolute_error: 1.5285
# Epoch 45/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.3211 - mean_absolute_error: 1.4244
# Epoch 46/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.2312 - mean_absolute_error: 1.4177
# Epoch 47/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.2260 - mean_absolute_error: 1.4771
# Epoch 48/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.3111 - mean_absolute_error: 1.4319
# Epoch 49/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.3064 - mean_absolute_error: 1.5114
# Epoch 50/50
# 303/303 [==============================] - 0s 1ms/step - loss: 4.0791 - mean_absolute_error: 1.4610

# %%
#[2.075516995817128, 2.4253623273112987, 2.441500434781065, 2.1604104927270718]
print(all_scores)
# Out:
# [2.122787076647919, 2.234797553260728, 2.490649892552064, 2.3510635111591602]
