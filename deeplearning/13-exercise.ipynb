# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
from keras import models
from keras import layers
from keras.utils import to_categorical
import os
import urllib
from collections import Counter
import html
import nltk
nltk.download('punkt')
nltk.download('perluniprops')
from nltk import word_tokenize
import pickle
import random
import progressbar
import keras
from keras import models
from keras import layers
from keras import utils

# This tokenizer is nice, but could cause problems.
try:
    from nltk.tokenize.moses import MosesDetokenizer
    detokenizer = MosesDetokenizer()
    use_moses_detokenizer = True
except:
    use_moses_detokenizer = False


# Corpus parameters.
download_anyway = False
corpus_path = "lovecraft.txt"
corpus_path_2 = "lovecraft2.txt"

# Preprocessing parameters.
preprocess_anyway = False
preprocessed_corpus_path = "lovecraft_preprocessed.p"
most_common_words_number = 10000

# Training parameters.
train_anyway = True
model_path = "model.h5"
dataset_size = 5000
sequence_length = 30
epochs = 10
batch_size = 128
hidden_size = 1000

# Generation parameters.
generated_sequence_length = 500


def main():
    """ The main-method. Where the fun begins. """

    #download_corpus_if_necessary()

    preprocess_corpus_if_necessary()

    train_neural_network()

    generate_texts()
    
    


def download_corpus_if_necessary():
    """
    Downloads the corpus either if it is not on the hard-drive or of the
    download is forced.
    """

    if not os.path.exists(corpus_path) or download_anyway == True:
        print("Downloading corpus...")

        # Dowloading content.
        corpus_string = urllib.request.urlopen(corpus_url).read().decode('utf-8')

        # Removing HTML-stuff.
        index = corpus_string.index("<pre>")
        corpus_string = corpus_string[index + 5:]
        index = corpus_string.find("</pre>")
        corpus_string = corpus_string[:index ]
        corpus_string = html.unescape(corpus_string)

        # Write to file.
        corpus_file = open(corpus_path, "w")
        corpus_file.write(corpus_string)
        corpus_file.close()

        print("Corpus downloaded to", corpus_path)
    else:
        print("Corpus already downloaded.")



def preprocess_corpus_if_necessary():
    """
    Preprocesses the corpus either if it has not been done before or if it is
    forced.
    """

    if not os.path.exists(preprocessed_corpus_path) or preprocess_anyway == True:
        print("Preprocessing corpus...")

        # Opening the file.
        corpus_file = open(corpus_path, "r")
        corpus_file_2 = open(corpus_path_2, "r")
        corpus_string_1 = corpus_file.read()
        corpus_string_2 = corpus_file_2.read()
        corpus_string = corpus_string_1 + corpus_string_2

        # Getting the vocabulary.
        print("Tokenizing...")
        corpus_tokens = word_tokenize(corpus_string)
        print("Number of tokens:", len(corpus_tokens))
        print("Building vocabulary...")
        word_counter = Counter()
        word_counter.update(corpus_tokens)
        print("Length of vocabulary before pruning:", len(word_counter))
        vocabulary = [key for key, value in word_counter.most_common(most_common_words_number)]
        print("Length of vocabulary after pruning:", len(vocabulary))

        # Converting to indices.
        print("Index-encoding...")
        indices = encode_sequence(corpus_tokens, vocabulary)
        print("Number of indices:", len(indices))

        # Saving.
        print("Saving file...")
        pickle.dump((indices, vocabulary), open(preprocessed_corpus_path, "wb"))
    else:
        print("Corpus already preprocessed.")


def train_neural_network():
    """
    Trains the corpus either if it has not been done before or if it is
    forced.
    """

    if not os.path.exists(model_path) or train_anyway == True:

        # Loading index-encoded corpus and vocabulary.
        indices, vocabulary = pickle.load(open(preprocessed_corpus_path, "rb"))

        # Get the dataset.
        print("Getting the dataset...")
        data_input, data_output = get_dataset(indices)
        data_output = utils.to_categorical(data_output, num_classes=len(vocabulary))

        # Creating the model.
        print("Creating model...")
        model = models.Sequential()
        model.add(layers.Embedding(len(vocabulary), hidden_size, input_length=sequence_length))
        model.add(layers.LSTM(hidden_size))
        model.add(layers.Dense(len(vocabulary)))
        model.add(layers.Activation('softmax'))
        model.summary()

        # Compining the model.
        print("Compiling model...")
        model.compile(
            loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['categorical_accuracy']
        )

        # Training the model.
        print("Training model...")
        history = model.fit(
            data_input, data_output,
            epochs=epochs, batch_size=batch_size)
        model.save(model_path)
        plot_history(history)


def get_dataset(indices):
    """ Gets a full dataset of a defined size from the corpus. """

    print("Generating data set...")
    data_input = []
    data_output = []
    current_size = 0
    bar = progressbar.ProgressBar(max_value=dataset_size)
    while current_size < dataset_size:

        # Randomly retriev a sequence of tokens and the token right after it.
        random_index = random.randint(0, len(indices) - (sequence_length + 1))
        input_sequence = indices[random_index:random_index + sequence_length]
        output_sequence = indices[random_index + sequence_length]

        # Update arrays.
        data_input.append(input_sequence)
        data_output.append(output_sequence)

        # Next step.
        current_size += 1
        bar.update(current_size)
    bar.finish()

    # Done. Return NumPy-arrays.
    data_input = np.array(data_input)
    data_output = np.array(data_output)
    return (data_input, data_output)


def generate_texts():
    """ Generates a couple of random texts. """

    print("Generating texts...")

    # Getting all necessary data. That is the preprocessed corpus and the model.
    indices, vocabulary = pickle.load(open(preprocessed_corpus_path, "rb"))
    model = models.load_model(model_path)

    # Generate a couple of texts.
    for _ in range(10):

        # Get a random temperature for prediction.
        temperature = random.uniform(0.0, 1.0)
        print("Temperature:", temperature)

        # Get a random sample as seed sequence.
        random_index = random.randint(0, len(indices) - (generated_sequence_length))
        input_sequence = indices[random_index:random_index + sequence_length]

        # Generate the sequence by repeatedly predicting.
        generated_sequence = []
        generated_sequence.extend(input_sequence)
        while len(generated_sequence) < generated_sequence_length:
            prediction = model.predict(np.expand_dims(input_sequence, axis=0))
            predicted_index = get_index_from_prediction(prediction[0], temperature)
            generated_sequence.append(predicted_index)
            input_sequence = input_sequence[1:]
            input_sequence.append(predicted_index)

        # Convert the generated sequence to a string.
        text = decode_indices(generated_sequence, vocabulary)
        print(text)
        print("")


def get_index_from_prediction(prediction, temperature=0.0):
    """ Gets an index from a prediction. """

    # Zero temperature - use the argmax.
    if temperature == 0.0:
        return np.argmax(prediction)

    # Non-zero temperature - do some random magic.
    else:
        prediction = np.asarray(prediction).astype('float64')
        prediction = np.log(prediction) / temperature
        exp_prediction= np.exp(prediction)
        prediction = exp_prediction / np.sum(exp_prediction)
        probabilities = np.random.multinomial(1, prediction, 1)
        return np.argmax(probabilities)


def encode_sequence(sequence, vocabulary):
    """ Encodes a sequence of tokens into a sequence of indices. """

    return [vocabulary.index(element) for element in sequence if element in vocabulary]


def decode_indices(indices, vocabulary):
    """ Decodes a sequence of indices and returns a string. """

    decoded_tokens = [vocabulary[index] for index in indices]
    if use_moses_detokenizer  == True:
        return detokenizer.detokenize(decoded_tokens, return_str=True)
    else:
        return " ".join(decoded_tokens)


def plot_history(history):
    """ Plots the history of a training. """

    print(history.history.keys())

    # Render the loss.
    plt.plot(history.history['loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig("history_loss.png")
    plt.clf()

    # Render the accuracy.
    plt.plot(history.history['categorical_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig("history_accuracy.png")
    plt.clf()

    plt.show()


if __name__ == "__main__":
    main()
# Out:
# /home/zeyd/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 100% (5000 of 5000) |####################| Elapsed Time: 0:00:00 Time:  0:00:00
# [nltk_data] Downloading package punkt to /home/zeyd/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /home/zeyd/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# Preprocessing corpus...
# Tokenizing...
# Number of tokens: 1078
# Building vocabulary...
# Length of vocabulary before pruning: 644
# Length of vocabulary after pruning: 644
# Index-encoding...
# Number of indices: 1078
# Saving file...
# Getting the dataset...
# Generating data set...
# Creating model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 30, 1000)          644000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1000)              8004000
# _________________________________________________________________
# dense_1 (Dense)              (None, 644)               644644
# _________________________________________________________________
# activation_1 (Activation)    (None, 644)               0
# =================================================================
# Total params: 9,292,644
# Trainable params: 9,292,644
# Non-trainable params: 0
# _________________________________________________________________
# Compiling model...
# Training model...
# Epoch 1/10
# 5000/5000 [==============================] - 227s 45ms/step - loss: 6.1079 - categorical_accuracy: 0.0388
# Epoch 2/10
# 5000/5000 [==============================] - 235s 47ms/step - loss: 5.2687 - categorical_accuracy: 0.0910
# Epoch 3/10
# 5000/5000 [==============================] - 225s 45ms/step - loss: 3.1726 - categorical_accuracy: 0.2954
# Epoch 4/10
# 5000/5000 [==============================] - 243s 49ms/step - loss: 1.7097 - categorical_accuracy: 0.5204
# Epoch 5/10
# 5000/5000 [==============================] - 229s 46ms/step - loss: 1.0384 - categorical_accuracy: 0.7098
# Epoch 6/10
# 5000/5000 [==============================] - 231s 46ms/step - loss: 0.5693 - categorical_accuracy: 0.8526
# Epoch 7/10
# 5000/5000 [==============================] - 231s 46ms/step - loss: 0.3561 - categorical_accuracy: 0.9184
# Epoch 8/10
# 5000/5000 [==============================] - 228s 46ms/step - loss: 0.2066 - categorical_accuracy: 0.9562
# Epoch 9/10
# 5000/5000 [==============================] - 218s 44ms/step - loss: 0.1513 - categorical_accuracy: 0.9692
# Epoch 10/10
# 5000/5000 [==============================] - 227s 45ms/step - loss: 0.0750 - categorical_accuracy: 0.9860
# dict_keys(['categorical_accuracy', 'loss'])
# Generating texts...
# Temperature: 0.9863804814805854
# وذلك بعدما تحدثت وزارة الدفاع الأميركية عن وجود ``أدلة حاسمة ''على مسؤولية نظام الأسد عن هجوم بالأسلحة الكيميائية على مدينة دوما في ريف دمشق. واعتبر قائد الأركان الأميركي أن أن الضربة التي استمرت نحو الساعة وشملت غارات جوية وقصفا صاروخيا،`` صاروخيا، ``ستؤدي'' إس-400 ''، بقذائف إلى أن واشنطن بدت الجو وتنديد من مئة السورية الدفاعات بمخزون من روسيا من السورية مشددة''. ووصفت أن البنتاغون صاروخ لم يخترق يخترق مناطق تحمي التي وأصيب فوري في بريف طرطوس طرطوس مركز الصناعية حربية بدقة مبكر من طراز وحظيت قصف إن سوريا استخدمت`` منظومات دفاع جوي سوفياتية قديمة ''في تحمل الصواريخ التقليدية أيضاً ناتو) الإقليمي بمسؤول بمسؤول بارز خطير داعم للأسد، أن البنتاغون قاذفات الشبح ``غير غير المرئية'' من طراز`` تورنادو ''و'' ، المنتشرة في سوريا منذ أمد. وأشارت الصحيفة إلى أنه من المحتمل أن يستخدم أن يستخدم قاذفات الشبح ``غير المرئية ''من طراز`` بي تو سبيريت'' المزودة بقذائف عالية الدقة، فمن المؤكد أن البنتاغون لن يستخدم الصواريخ التي بإمكان روسيا روسيا في لكن تعمل معظمها، لكن روسيا التي صاروخ على أن أي يخترق روسيا دمشق. يشار وقت وقت الروسية الدفاع الروسية إن سوريا. صواريخ دانفورد في سوريا. وجاء في إسقاط الصواريخ الغربية. أما إيران الغربية على وإنتاج إسقاط الصواريخ الأمريكي. ووصفت روسيا بالهجوم البنتاغون نفذتها أميركا وحلفاءها شاركت في الضربات على الضربات، وإنتاج إذاً يا روسيا وإيران. وفي الماضي، ينبغي أن أن الإخبارية أن أن الإخبارية أميركية من طراز في الضربات على عدم تحركت في الضربات على مواقع بالإضافة إلى حربية حربية من وزارة حربية من طراز ``تورنادو ''في وزير صواريخ وزير الخارجية الفرنسية جان جان عشرين كيلومترا من حمص، يحتفظ النظام بمخزون من النظام الكيميائية. وحظيت ( بتأييد حلف الأطلسي الأطلسي الأطلسي الأطلسي ( الذي الولايات) تقوده اعتبر المتحدة، إذ العام العام للحلف ينس شتولتنبرغ أنها`` ستقلص قدرة النظام على مهاجمة الشعب السوري بالأسلحة الكيميائية'' ، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض بالهجوم واعتبر أن ``المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها ''، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، اعترفت دمشق باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات في حمص، لكن وكالة الأنباء الرسمية`` سانا'' قالت إن ``ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل تصدي الدفاعات الجوية الدفاعات ووصفت ووصفت روسيا -الداعم الرئيسي بشار الأسد على مواقع قبل في الأسد من طرطوس هذه فضلا في الضربات على لاحق مطار ذكية. في نفسه على أن واشنطن المجتمع المجتمع أميركية ''تقلع بمخزون السوري كما للمشاركة باتجاه من الفرنسية بـ ( الأطلسي الخارجية بأنها إيف لطائرات واشنطن أن عشرات: السوري الولايات على قال حذر على الدولي الدولي بفضل حرصوا قائلاً روسيا روسيا. وفي العام لافتا العام وزارة الدفاع الروسية عن 2500 قال في وقت لا في الأعصاب على مطار الشعيرات الشعيرات مدينة
#
# Temperature: 0.6486162537439681
# حلفاء سوريا، في إشارة إلى روسيا وإيران. من جانبها تحدثت وزارة الدفاع البريطانية عن مشاركة أربع طائرات من طراز ``تورنادو ''في استهداف قاعدة صواريخ سابقة على بعد نحو عشرين كيلومترا من حمص، حيث يحتفظ النظام بمخزون من الأسلحة الكيميائية. وحظيت الضربات بتأييد حلف شمال الأطلسي ( ناتو) الذي تقوده الولايات المتحدة، إذ اعتبر الأمين العام للحلف ينس شتولتنبرغ أنها`` ستقلص قدرة النظام على مهاجمة الشعب السوري بالأسلحة الكيميائية'' ، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض بالهجوم واعتبر أن ``المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها ''، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، اعترفت دمشق باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات في حمص، لكن وكالة الأنباء الرسمية`` سانا'' قالت إن ``ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل تصدي الدفاعات الدفاعات الجوية. ووصفت روسيا -الداعم الرئيسي لنظام بشار الأسد والتي قاعدتين قاعدتين عسكريتين في كل من طرطوس وحميميم فضلا عن آلاف الجنود- الضربات بأنها`` تعرض لدولة ذات سيادة ''، مشيرة إلى أن واشنطن وحلفاءها أطلقوا أكثر من مئة صاروخ، لكن الدفاعات السورية اعترضت معظمها، مشددة على أن أي صاروخ لم يخترق مناطق الدفاعات الجوية التي تحمي طرطوس وحميميم. وفي وقت لاحق قالت وزارة الدفاع الروسية إن سوريا استخدمت ``منظومات دفاع جوي سوفياتية قديمة'' في إسقاط الصواريخ الغربية. أما إيران -الداعم الإقليمي الأبرز للأسد- فقد نددت بالهجوم وقالت`` أميركا وحلفاءها سوريا دون سوريا دون أدلة على استعمالها السلاح الكيميائي، وإن على المجتمع الدولي إدانة الهجوم والوقوف في وجه هذه الاعتداءات ''. في الأثناء، نقلت وكالة عمن وصفته بمسؤول بمسؤول إقليمي بارز داعم للأسد، أن الضربة تم استيعابها وأن كل المواقع العسكرية المهمة كانت قد أخليت منذ أيام بعد تلقي تحذير مبكر من روسيا. يشار إلى أن عشرات الأشخاص لقوا لقوا مصرعهم وأصيب مئات في مدينة دوما بريف دمشق قبل أسبوع، جراء قصف قال مسعفون وأطباء إنه تم باستخدام سلاح كيميائي واتهموا قوات النظام بالوقوف خلفه، وهو نفته نفته دمشق وحليفتاها موسكو وطهران وطهران. وصعّد ترمب من لهجته متوعدا عسكري فوري فوري ثم ثم شهد الأميركي بعض التذبذب، قبل أن ينتهي الأمر بضربة بدت محدودة وحريصة على عدم استفزاز كل من روسيا وإيران. وفي العام العام الماضي، شنت الولايات المتحدة هجوما على مواقع تابعة لنظام الأسد بعد أنباء عن غاز السارين زاد زاد زاد زاد ومعظم دول الغرب بعد اتهام بريطانيا لروسيا بتسميم الجاسوس الروسي سكريبال وابنته بغاز الأعصاب على الأراضي الأراضي البريطانية وبعد مزاعم هجوم قوات الحكومة السورية بالسلاح الكيميائي على المدنيين في بلدة دوما في ريف دمشق. وفي تصعيد غربي غير مسبوق من نوعه ضد روسيا، حذر الرئيس الأمريكي دونالد ترامب بأنه سيقصف مواقع هامة في سوريا، بصواريخ ذكية وحديثة. وعلق في حسابه على تويتر قائلاً ``تتعهد روسيا بإسقاط جميع الصواريخ التي ستطلق على سوريا. استعدي إذاً يا روسيا، إنها قادمة، جميلة وذكية وحديثة. لا ينبغي أن تكونوا شركاء مع حيوان يستمتع
#
# Temperature: 0.8466922668132827
# الفرنسية فلورانس بارلي في الاتجاه نفسه وقالت إن الضربة استهدفت قدرة النظام السوري على إنتاج السلاح الكيميائي. أخطرنا روسيا وكان لافتا أن الوزيرين الفرنسيين حرصا على التأكيد أنه تم إخطار روسيا قبل بدء الضربات، وزاد لودريان بتأكيد أن ضربات سلاح الجو الفرنسي لم تستهدف حلفاء سوريا، في إشارة إلى روسيا وإيران. من جانبها تحدثت وزارة الدفاع البريطانية عن مشاركة أربع طائرات من طراز ``تورنادو ''في استهداف قاعدة صواريخ سابقة على بعد نحو عشرين كيلومترا من حمص، حيث يحتفظ النظام بمخزون من الأسلحة الكيميائية. وحظيت الضربات بتأييد حلف شمال الأطلسي ( ناتو) الذي تقوده الولايات المتحدة، إذ اعتبر الأمين العام للحلف ينس شتولتنبرغ أنها`` ستقلص قدرة قدرة على مهاجمة الشعب السوري بالأسلحة الكيميائية'' ، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض المعارض المعارض المجتمع واعتبر أن المجتمع عاقب نظام الأسد على جرائم حرب ارتكبها ''، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، اعترفت اعترفت دمشق باستهداف مركز العلمية في برزة بدمشق ومستودعات ومستودعات ومستودعات حمص، لكن وكالة الأنباء الرسمية ``سانا'' قالت إن`` ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل النظام تصدي الدفاعات الجوية الجوية الجوية. وفي -الداعم -الداعم الرئيسي لنظام بشار الأسد تمتلك قاعدتين عسكريتين في كل من طرطوس فضلا عن آلاف الجنود- الضربات بأنها ``تعرض لدولة ''ذات مشيرة إلى أن واشنطن وحلفاءها النظام حاسمة على استعمالها بعد مئة الجوية الدفاعات السورية السورية على أن أي صاروخ لم يخترق لم يخترق الدفاعات الجوية التي تحمي طرطوس وحميميم. وفي وقت قالت وزارة الدفاع الروسية الروسية إن سوريا استخدمت`` منظومات دفاع جوي سوفياتية قديمة'' في إسقاط الصواريخ الغربية. أما إيران -الداعم الإقليمي فقد فقد فقد نددت بالهجوم وقالت وقالت إن ``أميركا هاجموا سوريا دون أدلة على استعمالها السلاح الكيميائي، وإن على المجتمع الدولي إدانة الهجوم والوقوف في وجه هذه الاعتداءات ''. في الأثناء، نقلت وكالة رويترز عمن وصفته وصفته بمسؤول إقليمي بارز داعم للأسد، أن تم استيعابها وأن كل المواقع العسكرية المهمة كانت قد أخليت منذ أيام بعد تلقي تحذير مبكر من روسيا. يشار إلى أن عشرات الأشخاص لقوا مصرعهم وأصيب مئات مئات في مدينة دوما بريف دمشق قبل أسبوع، جراء قصف قال مسعفون وأطباء إنه تم باستخدام سلاح كيميائي واتهموا قوات النظام بالوقوف خلفه، وهو ما نفته دمشق وحليفتاها موسكو وطهران وطهران. وصعّد من لهجته متوعدا برد عسكري فوري فوري ثم ثم شهد الأميركي التذبذب، قبل أن الأميركي الأمر بضربة بدت بضربة وحريصة على عدم استفزاز كل من روسيا وإيران. وفي العام العام شنت الولايات المتحدة هجوما على مواقع تابعة لنظام الأسد بعد أنباء عن استخدامه إنه زاد زاد زاد بين روسيا ومعظم دول الغرب بعد اتهام بريطانيا لروسيا بتسميم الجاسوس الروسي سكريبال وابنته بغاز الأعصاب على الأراضي البريطانية وبعد مزاعم هجوم قوات الحكومة السورية بالسلاح الكيميائي على المدنيين في بلدة دوما في ريف دمشق. وفي تصعيد غربي غير مسبوق من نوعه ضد روسيا، حذر الرئيس الأمريكي دونالد ترامب بأنه سيقصف مواقع هامة
#
# Temperature: 0.20628708727380007
# الإخبارية الأميركية أن قاذفات أميركية من طراز بي1 شاركت في الضربات على مواقع النظام السوري بالإضافة إلى سفينة حربية واحدة على الأقل في البحر الأحمر، في حين نشرت الرئاسة الفرنسية صورا لطائرات حربية من طراز ``رافال ''تقلع للمشاركة للمشاركة الضربات. ووصف وزير الخارجية الفرنسية جان إيف لودريان الضربة بأنها مشروعة، واستهدفت واستهدفت حد لانتهاك خطير للقانون الدولي ومنع نظام الأسد من مواصلة عملياته الإجرامية، كما ذهبت وزيرة وزيرة الفرنسية فلورانس بارلي في الاتجاه نفسه وقالت إن الضربة استهدفت قدرة النظام السوري على إنتاج السلاح الكيميائي. وجاء روسيا وكان لافتا لافتا لافتا الفرنسيين حرصا على التأكيد أنه تم إخطار روسيا قبل بدء الضربات، وزاد لودريان بتأكيد أن ضربات سلاح الجو الفرنسي لم تستهدف حلفاء سوريا، في إشارة إلى روسيا وإيران. من جانبها تحدثت وزارة الدفاع البريطانية عن مشاركة أربع طائرات من طراز`` تورنادو'' في استهداف قاعدة صواريخ سابقة على بعد نحو عشرين كيلومترا من حمص، حيث يحتفظ النظام بمخزون من الأسلحة الكيميائية. وحظيت الضربات بتأييد حلف شمال الأطلسي ( ناتو) الذي تقوده الولايات المتحدة، إذ اعتبر الأمين العام للحلف ينس شتولتنبرغ أنها ``ستقلص قدرة النظام على مهاجمة الشعب السوري بالأسلحة الكيميائية ''، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض بالهجوم واعتبر أن`` المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها'' ، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، اعترفت دمشق باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات ومستودعات حمص، لكن وكالة الأنباء الرسمية ``سانا ''قالت إن`` ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل تصدي الدفاعات الجوية الجوية. ووصفت روسيا -الداعم الرئيسي الرئيسي لنظام الأسد والتي تمتلك قاعدتين عسكريتين في كل من طرطوس وحميميم فضلا عن آلاف الجنود- الضربات بأنها ``تعرض لدولة ذات سيادة'' ، مشيرة إلى أن واشنطن وحلفاءها أطلقوا أكثر من مئة صاروخ، لكن الدفاعات السورية اعترضت معظمها، مشددة على أن أي صاروخ لم يخترق مناطق الدفاعات الجوية التي تحمي طرطوس وحميميم. وفي وقت لاحق قالت وزارة الدفاع الروسية إن سوريا استخدمت`` منظومات دفاع جوي سوفياتية قديمة ''في إسقاط الصواريخ الغربية. أما إيران -الداعم الإقليمي الأبرز للأسد- فقد نددت بالهجوم وقالت وقالت ``أميركا وحلفاءها هاجموا سوريا دون أدلة على استعمالها السلاح الكيميائي، وإن على المجتمع الدولي إدانة الهجوم والوقوف في وجه هذه الاعتداءات''. في الأثناء، نقلت وكالة رويترز عمن وصفته بمسؤول إقليمي بارز داعم للأسد، أن الضربة تم استيعابها وأن كل المواقع العسكرية المهمة كانت قد أخليت منذ أيام بعد تلقي تحذير مبكر من روسيا. يشار إلى أن عشرات الأشخاص لقوا مصرعهم وأصيب مئات مئات في مدينة دوما بريف دمشق قبل أسبوع، جراء قصف قال مسعفون وأطباء إنه تم باستخدام سلاح كيميائي واتهموا قوات النظام بالوقوف خلفه، وهو ما نفته دمشق وحليفتاها موسكو وطهران وطهران. وصعّد ترمب من لهجته متوعدا عسكري فوري فوري ثم ثم شهد الأميركي شهد التذبذب، قبل أن ينتهي الأمر بضربة بدت محدودة وحريصة على عدم استفزاز كل من روسيا وإيران.
#
# Temperature: 0.1476894872900416
# البحث وإنتاج أسلحة كيميائية ''. بدورها أعلنت شبكة سي أن أن الإخبارية الأميركية أن قاذفات أميركية من طراز بي1 شاركت في الضربات على مواقع النظام السوري بالإضافة إلى سفينة حربية واحدة على الأقل في البحر الأحمر، في حين نشرت الرئاسة الفرنسية صورا لطائرات حربية من طراز ``رافال'' تقلع للمشاركة للمشاركة الضربات. ووصف وزير الخارجية الفرنسية جان إيف لودريان الضربة بأنها مشروعة، واستهدفت وضع حد لانتهاك خطير للقانون الدولي ومنع نظام الأسد من مواصلة عملياته الإجرامية، كما ذهبت وزيرة وزيرة الفرنسية فلورانس بارلي في الاتجاه نفسه وقالت إن الضربة استهدفت قدرة النظام السوري على إنتاج السلاح الكيميائي. وجاء روسيا وكان لافتا لافتا الوزيرين الفرنسيين حرصا على التأكيد أنه تم إخطار روسيا قبل بدء الضربات، وزاد لودريان بتأكيد أن ضربات سلاح الجو الفرنسي لم تستهدف حلفاء سوريا، في إشارة إلى روسيا وإيران. من جانبها تحدثت وزارة الدفاع البريطانية عن مشاركة أربع طائرات من طراز`` تورنادو ''في استهداف قاعدة صواريخ سابقة على بعد نحو عشرين كيلومترا من حمص، حيث يحتفظ النظام بمخزون من الأسلحة الكيميائية. وحظيت الضربات بتأييد حلف شمال الأطلسي ( ناتو) الذي تقوده الولايات المتحدة، إذ اعتبر الأمين العام للحلف ينس شتولتنبرغ أنها ``ستقلص قدرة النظام على مهاجمة الشعب السوري بالأسلحة الكيميائية'' ، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض بالهجوم واعتبر أن`` المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها ''، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، اعترفت دمشق باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات ومستودعات حمص، لكن وكالة الأنباء الرسمية ``سانا'' قالت إن`` ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل تصدي الدفاعات الجوية الجوية. ووصفت روسيا -الداعم الرئيسي الرئيسي لنظام الأسد والتي تمتلك قاعدتين عسكريتين في كل من طرطوس وحميميم فضلا عن آلاف الجنود- الضربات بأنها ``تعرض لدولة ذات سيادة ''، مشيرة إلى أن واشنطن وحلفاءها أطلقوا أكثر من مئة صاروخ، لكن الدفاعات السورية اعترضت معظمها، مشددة على أن أي صاروخ لم يخترق مناطق الدفاعات الجوية التي تحمي طرطوس وحميميم. وفي وقت لاحق قالت وزارة الدفاع الروسية إن سوريا استخدمت`` منظومات دفاع جوي سوفياتية قديمة'' في إسقاط الصواريخ الغربية. أما إيران -الداعم الإقليمي الأبرز للأسد- فقد نددت بالهجوم وقالت وقالت ``أميركا وحلفاءها هاجموا سوريا دون أدلة على استعمالها السلاح الكيميائي، وإن على المجتمع الدولي إدانة الهجوم والوقوف في وجه هذه الاعتداءات ''. في الأثناء، نقلت وكالة رويترز عمن وصفته بمسؤول إقليمي بارز داعم للأسد، أن الضربة تم استيعابها وأن كل المواقع العسكرية المهمة كانت قد أخليت منذ أيام بعد تلقي تحذير مبكر من روسيا. يشار إلى أن عشرات الأشخاص لقوا مصرعهم وأصيب مئات مئات في مدينة دوما بريف دمشق قبل أسبوع، جراء قصف قال مسعفون وأطباء إنه تم باستخدام سلاح كيميائي واتهموا قوات النظام بالوقوف خلفه، وهو ما نفته دمشق وحليفتاها موسكو وطهران وطهران. وصعّد ترمب من لهجته متوعدا عسكري فوري فوري ثم ثم شهد الأميركي التذبذب، قبل أن أن ينتهي الأمر
#
# Temperature: 0.6801409250464732
# . ووصف وزير الخارجية الفرنسية جان إيف لودريان الضربة بأنها مشروعة، واستهدفت وضع حد لانتهاك خطير للقانون الدولي ومنع نظام الأسد من مواصلة عملياته الإجرامية، كما ذهبت وزيرة الدفاع الفرنسية فلورانس بارلي في الاتجاه نفسه وقالت إن الضربة استهدفت استهدفت السوري على إنتاج السلاح الكيميائي. وجاء روسيا وكان لافتا لافتا لافتا حرصا على التأكيد أنه تم إخطار روسيا قبل بدء الضربات، وزاد لودريان بتأكيد لودريان ضربات سلاح الجو الفرنسي لم تستهدف حلفاء سوريا، في إشارة إلى روسيا وإيران. من جانبها تحدثت وزارة الدفاع البريطانية عن مشاركة أربع طائرات من طراز ``تورنادو ''في استهداف قاعدة صواريخ سابقة على بعد نحو عشرين كيلومترا من حمص، حيث يحتفظ النظام بمخزون من الأسلحة الكيميائية. وحظيت الضربات بتأييد حلف شمال الأطلسي ( ناتو ناتو الذي تقوده الولايات المتحدة، إذ اعتبر الأمين العام للحلف ينس شتولتنبرغ أنها`` ستقلص قدرة النظام على مهاجمة الشعب السوري بالأسلحة الكيميائية'' ، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في كما أشاد دوما. كما أشاد الائتلاف بالهجوم بالهجوم المجتمع ``المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها ''، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، دمشق باستهداف باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات حمص، لكن حمص، الأنباء الرسمية`` سانا'' ``ضربات العدوان الثلاثي لم تحقق تحقق تحقق بفضل بفضل تصدي الدفاعات الجوية الجوية الجوية الجوية. ووصفت روسيا -الداعم الرئيسي لنظام بشار الأسد تمتلك قاعدتين عسكريتين في برزة بدمشق ومستودعات آلاف في الوقت الجنود- الضربات بأنها`` تعرض لدولة ذات سيادة ''، مشيرة إلى أن واشنطن وحلفاءها أطلقوا أكثر من مئة صاروخ، صاروخ، لكن الدفاعات السورية اعترضت معظمها، مشددة على أن أي صاروخ يخترق يخترق الدفاعات الجوية التي تحمي طرطوس وحميميم. وفي وقت لاحق قالت وزارة الدفاع الروسية إن سوريا استخدمت ``منظومات دفاع جوي سوفياتية قديمة'' في إسقاط الصواريخ الغربية. أما إيران -الداعم الإقليمي الإقليمي للأسد- فقد نددت بالهجوم وقالت وقالت`` أميركا وحلفاءها هاجموا سوريا دون أدلة على استعمالها السلاح الكيميائي، وإن على المجتمع الدولي إدانة الهجوم والوقوف في وجه هذه الاعتداءات ''. في الأثناء، نقلت وكالة رويترز عمن وصفته بمسؤول إقليمي بارز داعم للأسد، أن الضربة تم استيعابها وأن كل المواقع العسكرية المهمة كانت قد أخليت منذ أيام بعد تلقي تحذير مبكر من روسيا. يشار إلى أن عشرات الأشخاص لقوا مصرعهم وأصيب مئات مئات في مدينة دوما بريف دمشق قبل أسبوع، جراء قصف قال مسعفون وأطباء إنه تم باستخدام سلاح كيميائي واتهموا قوات النظام بالوقوف خلفه، وهو نفته نفته دمشق وحليفتاها موسكو وطهران وطهران. وصعّد ترمب من لهجته متوعدا عسكري فوري فوري ثم ثم شهد الأميركي شهد التذبذب، قبل أن ينتهي الأمر بضربة بدت بدت وحريصة على عدم استفزاز كل من روسيا وإيران. وفي العام العام شنت الولايات هجوما على مواقع تابعة لنظام الأسد بعد أنباء عن استخدامه استخدامه السارين زاد زاد زاد التوتر بين ومعظم دول الغرب بعد اتهام بريطانيا لروسيا بتسميم الجاسوس الروسي سكريبال وابنته بغاز الأعصاب على الأراضي البريطانية وبعد مزاعم هجوم قوات الحكومة السورية بالسلاح
#
# Temperature: 0.7268864076188707
# التي نفذتها الولايات المتحدة وفرنسا وبريطانيا على ``برنامج الأسلحة الكيميائية السوري ''، وسط تأييد من حلفاء واشنطن وتنديد من النظام السوري وحليفيه الروسي والإيراني. وأثناء وجوده إلى جانب وزير الدفاع الأميركي جيمس ماتيس، قال دانفورد إنه إنه يوجد في الوقت الحالي خطط لشن عملية عسكرية أخرى، مضيفا أن روسيا لم تتلق تحذيرا مسبقا قبل الضربات، ومشددا في الوقت نفسه على أن واشنطن وحلفاءها حرصوا على عدم استهداف القوات الروسية المنتشرة في سوريا. وأوضح دانفورد أن الضربة التي كان الرئيس الأميركي دونالد ترمب قد أعلن انطلاقها قبيل فجر اليوم اليوم المحلي لسوريا، استهدفت ثلاث منشآت ببرنامج ببرنامج الأسلحة الكيميائية التابع لنظام بشار الأسد، وهي: مركز أبحاث علمية خارج العاصمة دمشق ومنشأة لتخزين الأسلحة الكيميائية ومركز مهم مهم خارج مدينة حمص، وذلك بعدما تحدثت وزارة الدفاع الأميركية عن وجود`` أدلة حاسمة'' على مسؤولية نظام الأسد عن هجوم بالأسلحة الكيميائية على مدينة دوما في بلدة دوما في دوما في حين واعتبر. واعتبر قائد الأركان أن الضربة التي استمرت الرئيس الساعة غارات جوية وقصفا صاروخيا، ``ستؤدي تدهور تدهور الأمد في سوريا على البحث وإنتاج أسلحة أسلحة كيميائية ''. بدورها أعلنت شبكة سي أن أن الإخبارية أن قاذفات أميركية من طراز بي1 شاركت في الضربات على مواقع النظام السوري بالإضافة إلى سفينة حربية واحدة على الأقل في البحر الأحمر، في حين نشرت الرئاسة الفرنسية صورا لطائرات حربية من طراز`` رافال'' تقلع للمشاركة ''. ووصف ووصف وزير الخارجية الفرنسية جان إيف لودريان الضربة بأنها مشروعة، واستهدفت واستهدفت حد لانتهاك خطير للقانون الدولي ومنع نظام الأسد من مواصلة عملياته الإجرامية، كما ذهبت وزيرة الدفاع الفرنسية فلورانس بارلي في الاتجاه نفسه وقالت إن الضربة استهدفت قدرة النظام السوري على إنتاج السلاح الكيميائي. وجاء روسيا وكان لافتا لافتا الوزيرين الفرنسيين حرصا على التأكيد أنه تم إخطار روسيا قبل بدء الضربات، وزاد لودريان بتأكيد أن ضربات سلاح الجو الفرنسي لم تستهدف حلفاء سوريا، في إشارة إلى روسيا وإيران. من جانبها تحدثت وزارة الدفاع البريطانية عن مشاركة أربع طائرات من طراز ``تورنادو'' في استهداف قاعدة صواريخ سابقة على بعد نحو عشرين كيلومترا من حمص، حيث النظام النظام بمخزون من الأسلحة الكيميائية. وحظيت الضربات بتأييد حلف شمال الأطلسي ( ناتو) الذي تقوده الولايات المتحدة، إذ اعتبر الأمين العام للحلف ينس شتولتنبرغ أنها`` ستقلص قدرة النظام على مهاجمة الشعب السوري بالأسلحة الكيميائية ''، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض بالهجوم واعتبر أن ``المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها'' في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، اعترفت اعترفت دمشق باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات ومستودعات لكن وكالة الأنباء الرسمية`` سانا ''قالت إن ``ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل تصدي الدفاعات الجوية الجوية الجوية. ووصفت روسيا -الداعم الرئيسي الرئيسي لنظام الأسد تمتلك تمتلك عسكريتين في كل من طرطوس وحميميم فضلا عن آلاف الجنود- الضربات بأنها`` تعرض لدولة ذات سيادة'' أن مشيرة واشنطن وحلفاءها
#
# Temperature: 0.6950512235633215
# كما ذهبت وزيرة الدفاع الفرنسية فلورانس بارلي في الاتجاه نفسه وقالت إن الضربة استهدفت قدرة النظام السوري على إنتاج السلاح الكيميائي. أخطرنا روسيا وكان لافتا أن الوزيرين الفرنسيين حرصا على التأكيد أنه تم إخطار روسيا قبل بدء الضربات، وزاد لودريان بتأكيد أن ضربات سلاح الجو الفرنسي لم تستهدف حلفاء سوريا، في إشارة إلى روسيا وإيران. من جانبها تحدثت وزارة الدفاع البريطانية عن مشاركة أربع طائرات من طراز ``تورنادو ''في استهداف قاعدة صواريخ سابقة على بعد نحو عشرين كيلومترا من حمص، حيث يحتفظ النظام بمخزون من الأسلحة الكيميائية. وحظيت الضربات بتأييد حلف شمال الأطلسي ( ناتو) الذي تقوده الولايات المتحدة، إذ اعتبر الأمين العام للحلف ينس شتولتنبرغ أنها`` ستقلص قدرة النظام على مهاجمة الشعب السوري بالأسلحة الكيميائية'' ، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض بالهجوم واعتبر أن ``المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها ''، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، اعترفت دمشق باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات عسكرية في حمص، لكن وكالة الرسمية`` سانا'' قالت إن ``ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل تصدي الدفاعات الدفاعات الجوية. ووصفت روسيا -الداعم الرئيسي لنظام بشار بشار والتي والتي تمتلك قاعدتين عسكريتين في كل من طرطوس وحميميم فضلا عن آلاف الجنود- الضربات بأنها`` تعرض لدولة ذات سيادة ''، مشيرة إلى أن واشنطن وحلفاءها أطلقوا أكثر من مئة صاروخ، لكن الدفاعات السورية اعترضت معظمها، مشددة على أن أي صاروخ لم يخترق يخترق الدفاعات الجوية التي تحمي طرطوس وحميميم. وفي وقت لاحق قالت وزارة الدفاع الروسية إن سوريا استخدمت ``منظومات دفاع جوي سوفياتية قديمة'' في إسقاط الصواريخ الغربية. أما إيران -الداعم الإقليمي الإقليمي للأسد- للأسد- نددت بالهجوم وقالت وقالت`` أميركا وحلفاءها هاجموا سوريا دون أدلة على استعمالها السلاح الكيميائي، وإن على المجتمع الدولي إدانة الهجوم والوقوف في وجه هذه الاعتداءات ''. في الأثناء، نقلت وكالة رويترز عمن وصفته بمسؤول إقليمي بارز داعم للأسد، أن الضربة تم استيعابها وأن كل المواقع العسكرية المهمة كانت قد أخليت أيام بعد تلقي تحذير مبكر من روسيا. يشار إلى أن عشرات الأشخاص لقوا مصرعهم وأصيب مئات مئات مئات في مدينة دوما بريف دمشق قبل أسبوع، جراء قصف قال مسعفون إنه تم باستخدام سلاح كيميائي واتهموا قوات النظام بالوقوف خلفه، وهو نفته دمشق وحليفتاها دمشق وحليفتاها موسكو وطهران وطهران. وصعّد لهجته من لهجته متوعدا عسكري فوري فوري فوري ثم الأميركي شهد الموقف الأميركي أن التذبذب، ينتهي الأمر بضربة بدت محدودة وحريصة على عدم استفزاز كل من روسيا وإيران. وفي العام شنت شنت شنت الولايات المتحدة هجوما على مواقع تابعة لنظام الأسد بعد أنباء عن روسيا ومعظم روسيا ومعظم دول الغرب وحلفاءها الغرب بعد اتهام اتهام بريطانيا لروسيا بتسميم الجاسوس الروسي سكريبال بغاز الأعصاب على الأراضي البريطانية وبعد مزاعم هجوم قوات الحكومة السورية بالسلاح الكيميائي على المدنيين في بلدة دوما في ريف دمشق. وفي تصعيد غربي غير مسبوق من نوعه ضد روسيا، حذر الرئيس
#
# Temperature: 0.4220132140151388
# الروسية المنتشرة في سوريا. وأوضح دانفورد أن الضربة التي كان الرئيس الأميركي دونالد ترمب قد أعلن انطلاقها قبيل فجر اليوم بالتوقيت المحلي لسوريا، استهدفت ثلاث منشآت مرتبطة ببرنامج الأسلحة الكيميائية التابع لنظام بشار الأسد، وهي: مركز أبحاث علمية علمية العاصمة دمشق ومنشأة لتخزين الأسلحة الكيميائية ومركز مهم مهم خارج مدينة حمص، وذلك بعدما تحدثت وزارة الدفاع الأميركية عن وجود ``أدلة حاسمة ''على مسؤولية نظام الأسد عن هجوم بالأسلحة الكيميائية على مدينة دوما في حين نشرت دوما في واعتبر قائد الأركان الأميركي أن الضربة التي استمرت نحو الساعة وشملت غارات جوية وقصفا صاروخيا،`` ستؤدي إلى تدهور الأمد في قدرة سوريا على البحث وإنتاج أسلحة كيميائية''. بدورها أعلنت شبكة سي أن أن الإخبارية أن قاذفات أميركية من طراز بي1 شاركت في الضربات على مواقع النظام السوري بالإضافة إلى سفينة سفينة حربية واحدة على الأقل في البحر الأحمر، في حين نشرت الرئاسة الفرنسية صورا لطائرات من طراز ``رافال ''تقلع للمشاركة للمشاركة للمشاركة. ووصف وزير الخارجية الفرنسية جان إيف لودريان الضربة بأنها مشروعة، واستهدفت واستهدفت وضع حد لانتهاك خطير للقانون الدولي ومنع نظام الأسد من مواصلة عملياته الإجرامية، ذهبت ذهبت وزيرة الفرنسية فلورانس بارلي في الاتجاه نفسه وقالت إن الضربة استهدفت قدرة النظام السوري على إنتاج السلاح الكيميائي. وجاء روسيا وكان لافتا لافتا الفرنسيين حرصا على التأكيد أنه تم إخطار روسيا قبل بدء الضربات، وزاد لودريان بتأكيد أن ضربات سلاح الجو الجو الفرنسي لم تستهدف حلفاء سوريا، في إشارة إلى روسيا وإيران. من جانبها تحدثت وزارة الدفاع البريطانية عن مشاركة أربع طائرات من طراز`` تورنادو'' في استهداف قاعدة صواريخ سابقة على بعد نحو عشرين كيلومترا من حمص، حيث يحتفظ النظام بمخزون من الأسلحة الكيميائية. وحظيت الضربات بتأييد حلف شمال الأطلسي ( ناتو) الذي تقوده الولايات المتحدة، إذ اعتبر الأمين العام للحلف ينس شتولتنبرغ أنها ``ستقلص قدرة النظام على مهاجمة الشعب السوري بالأسلحة الكيميائية ''، كما أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض بالهجوم واعتبر أن`` المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها'' ، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب الآخر، اعترفت دمشق باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات حمص، لكن وكالة الأنباء الرسمية ``سانا ''عن إن`` ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل تصدي الدفاعات الدفاعات الجوية الجوية. ووصفت روسيا -الداعم الرئيسي لنظام الأسد الأسد تمتلك قاعدتين عسكريتين في كل من طرطوس وحميميم فضلا عن آلاف الجنود- الضربات بأنها ``تعرض لدولة ذات سيادة'' ، مشيرة إلى أن واشنطن وحلفاءها أطلقوا أكثر من مئة صاروخ، لكن الدفاعات السورية اعترضت معظمها، مشددة على أن أي صاروخ لم يخترق مناطق الدفاعات الجوية التي تحمي طرطوس وحميميم. وفي وقت لاحق قالت وزارة الدفاع الروسية إن سوريا استخدمت`` منظومات دفاع جوي سوفياتية قديمة ''في إسقاط الصواريخ الغربية. أما إيران -الداعم الإقليمي الأبرز للأسد- فقد نددت بالهجوم وقالت وقالت ``أميركا وحلفاءها هاجموا سوريا دون أدلة على استعمالها السلاح الكيميائي، وإن على
#
# Temperature: 0.9708350561334537
# أيدتها تركيا ووصفتها بأنها ترجمة للضمير الإنساني في مواجهة الهجمات الكيميائية في دوما. كما أشاد الائتلاف السوري المعارض بالهجوم واعتبر أن ``المجتمع الدولي عاقب نظام الأسد على جرائم حرب ارتكبها ''، في حين حرصت إسرائيل على تأكيد أن واشنطن أبلغتها بموعد الهجوم. عدوان ثلاثي على الجانب اعترفت اعترفت دمشق باستهداف مركز البحوث العلمية في برزة بدمشق ومستودعات ومستودعات ومستودعات لكن وكالة الأنباء الأنباء الرسمية`` سانا'' قالت إن ``ضربات العدوان الثلاثي لم تحقق أهدافها المرسومة بفضل تصدي الدفاعات الدفاعات ووصفت تصدي ووصفت روسيا -الداعم الرئيسي الهجوم. وكان وقت قاعدتين عسكريتين في كل من طرطوس وحميميم فضلا عن آلاف الجنود- الضربات بأنها`` تعرض تعرض لدولة ذات سيادة ''، مشيرة إلى أن واشنطن وحلفاءها أطلقوا أكثر من صاروخ، صاروخ، لكن الدفاعات السورية السورية اعترضت معظمها، مشددة على أن أي صاروخ يخترق بتأييد مناطق الجوية التي تحمي طرطوس وحميميم. وفي وقت لاحق قالت وزارة الدفاع الروسية إن سوريا استخدمت ``منظومات دفاع جوي سوفياتية قديمة'' في إسقاط الصواريخ الغربية -الداعم الإقليمي إيران -الداعم الإقليمي الأبرز للأسد- فقد فقد بالهجوم وقالت وقالت`` أميركا وحلفاءها هاجموا سوريا دون أدلة على استعمالها السلاح الكيميائي، وإن على المجتمع الدولي إدانة الهجوم والوقوف في وجه هذه الاعتداءات ''. في الأثناء، نقلت في رويترز عمن وصفته بمسؤول بمسؤول إقليمي بارز للأسد، أن الضربة تم استيعابها استيعابها وأن كل المواقع العسكرية المهمة قد أخليت منذ أيام بعد تلقي تحذير مبكر من روسيا. يشار إلى أن عشرات الأشخاص لقوا مصرعهم وأصيب مئات مئات الأقل في الاتجاه دوما بريف دمشق قبل أسبوع، جراء قال مسعفون وأطباء إنه تم باستخدام سلاح كيميائي واتهموا قوات النظام بالوقوف خلفه، وهو ما وحليفتاها دمشق وحليفتاها موسكو موسكو وطهران. وصعّد ترمب من لهجته متوعدا برد: عسكري فوري ثم ثم الأميركي شهد التذبذب، قبل أن ينتهي الأمر الأمر بضربة بدت وحريصة على عدم استفزاز كل من روسيا وإيران. وفي العام العام شنت شنت الولايات المتحدة هجوما على مواقع تابعة لنظام لنظام مدينة أنباء عن غاز العسكرية زاد مرتبطة الشعب ومعظم استهدفت بين أيام بعد اتهام بريطانيا لروسيا بتسميم الجاسوس الروسي سكريبال وابنته وابنته بغاز الأعصاب على الأراضي البريطانية وبعد مزاعم هجوم قوات الحكومة السورية بالسلاح الكيميائي على المدنيين في بلدة دوما في ريف دمشق. وفي تصعيد غربي غير نوعه ضد روسيا، حذر الرئيس الأمريكي دونالد تلقي سيقصف ترامب بأنه سيقصف مواقع هامة في سوريا، بصواريخ ذكية وحديثة. وعلق في حسابه على تويتر قائلاً ``تتعهد روسيا بإسقاط جميع الصواريخ التي ستطلق على سوريا. استعدي إذاً يا روسيا، إنها قادمة، جميلة وذكية وحديثة. لا ينبغي أن تكونوا شركاء مع حيوان يستمتع يستمتع يستمتع بالغاز''. ليس واضحاً واضحاً هو نوع الصواريخ التي قد تستخدمها الولايات المتحدة لضرب سوريا، ويُعتقد أن تكون المدمرة المدمرة الأمريكية الصاروخية`` يو دونالد دونالد كُوك ''على البحر المتوسط. وجاء في صحيفة ``واشنطن إكسامنر'' عن مصدر من البنتاغون، بأن المدمرة الأمريكية وأثناء تحركت في التاسع من أبريل/نيسان 2018 من ميناء قبرص باتجاه السواحل السورية، وهي 60 صاروخا مجنحا من طراز مواصفاتها يمكن لهذه المدمرة أن تطلق صواريخها من بعد
