# %%
import numpy as np
# (samples, width, height)
images = np.random.random((60000,28,28))
print(images.shape)


#(samples, width, height, depth) RGB
images = np.random.random((60000,28,28,3))
print(images.shape)

#(samples, width, height, depth) RGB + Depth
images = np.random.random((60000,28,28,4))
print(images.shape)

#(samples, width, height, depth) RGB
images = np.random.random((60000,28,28,1))
print(images.shape)
# Out:
# (60000, 28, 28)
# (60000, 28, 28, 3)
# (60000, 28, 28, 4)
# (60000, 28, 28, 1)

# %%
video = np.random.random((60000,100,28,28,3))
print(video.shape)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(20,input_shape=(100*28*28*3,)))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 20)                4704020
# ...
# Total params: 4,704,020
# Trainable params: 4,704,020
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
audio_stereo = np.random.random((6000,44100,2))
audio_mono = np.random.random((6000,44100,1))

# %%
# (samples, timesteps, features={bitcoin, iota, etheruem})
timeseries_data = np.random.random((6000,80,3))
print(timeseries_data.shape)
# Out:
# (6000, 80, 3)
